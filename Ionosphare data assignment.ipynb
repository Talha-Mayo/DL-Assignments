# %%
#Import dataset

import pandas as pd

data = pd.read_csv('ionosphere_data.csv')
data.head()
# Out:
#    feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0         1         0   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1         1         0   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2         1         0   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3         1         0   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4         1         0   1.00000  -0.02401   0.94140   0.06531   0.92106
#
#    feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# 0  -0.37708   1.00000    0.03760  ...   -0.51171    0.41078   -0.46168
# 1  -0.93597   1.00000   -0.04549  ...   -0.26569   -0.20468   -0.18401
# 2  -0.12062   0.88965    0.01198  ...   -0.40220    0.58984   -0.22145
# 3  -1.00000   0.00000    0.00000  ...    0.90695    0.51613    1.00000
# 4  -0.23255   0.77152   -0.16399  ...   -0.65158    0.13290   -0.53206
#
#    feature29  feature30  feature31  feature32  feature33  feature34  label
# ...

# %%
data.shape
# Out:
# (351, 35)

# %%
#Checck any null value in our data set. in this case there is no null value

data.isnull().values.any()
# Out:
# False

# %%
#Here we can see that all columns have integer or float type values except last one
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature2   351 non-null    int64
#  2   feature3   351 non-null    float64
#  3   feature4   351 non-null    float64
#  4   feature5   351 non-null    float64
#  5   feature6   351 non-null    float64
#  6   feature7   351 non-null    float64
#  7   feature8   351 non-null    float64
#  8   feature9   351 non-null    float64
#  9   feature10  351 non-null    float64
#  10  feature11  351 non-null    float64
#  11  feature12  351 non-null    float64
#  12  feature13  351 non-null    float64
#  13  feature14  351 non-null    float64
#  14  feature15  351 non-null    float64
#  15  feature16  351 non-null    float64
#  16  feature17  351 non-null    float64
#  17  feature18  351 non-null    float64
#  18  feature19  351 non-null    float64
# ...

# %%
#Converting string data type into integer type

from sklearn.preprocessing import LabelEncoder

lableencoder=LabelEncoder()

data['label']=lableencoder.fit_transform(data['label'])

# %%
dataset
# Out:
#      feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0           1         0   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1           1         0   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2           1         0   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3           1         0   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4           1         0   1.00000  -0.02401   0.94140   0.06531   0.92106
# ..        ...       ...       ...       ...       ...       ...       ...
# 346         1         0   0.83508   0.08298   0.73739  -0.14706   0.84349
# 347         1         0   0.95113   0.00419   0.95183  -0.02723   0.93438
# 348         1         0   0.94701  -0.00034   0.93207  -0.03227   0.95177
# 349         1         0   0.90608  -0.01657   0.98122  -0.01989   0.95691
# 350         1         0   0.84710   0.13533   0.73638  -0.06151   0.87873
#
#      feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# ...

# %%
#Spliting data into data and labels

input_data=data.iloc[:,0:34]

output_labels=data.iloc[:,34:35]

# %%
#Spliting data and labels into test data,test labels, train data and train labels

train_data = input_data[0:210]
train_labels = output_labels[0:210]

test_data = input_data[210:]
test_labels= output_labels[210:]

# %%
#Creating model

from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_dim = 34))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
#Compiling model

model.compile(optimizer='rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

# %%
#Fitting data into model

model.fit(train_data, train_labels, epochs=100, batch_size=5)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 0s 749us/step - loss: 0.7210 - accuracy: 0.4924
# Epoch 2/100
# 42/42 [==============================] - 0s 592us/step - loss: 0.6836 - accuracy: 0.5801
# Epoch 3/100
# 42/42 [==============================] - 0s 561us/step - loss: 0.6039 - accuracy: 0.6815
# Epoch 4/100
# 42/42 [==============================] - 0s 598us/step - loss: 0.5468 - accuracy: 0.7678
# Epoch 5/100
# 42/42 [==============================] - 0s 617us/step - loss: 0.5084 - accuracy: 0.8387
# Epoch 6/100
# 42/42 [==============================] - 0s 590us/step - loss: 0.5040 - accuracy: 0.8114
# Epoch 7/100
# 42/42 [==============================] - 0s 561us/step - loss: 0.4512 - accuracy: 0.8583
# Epoch 8/100
# 42/42 [==============================] - 0s 585us/step - loss: 0.4462 - accuracy: 0.8450
# Epoch 9/100
# 42/42 [==============================] - 0s 585us/step - loss: 0.4271 - accuracy: 0.8723
# Epoch 10/100
# ...

# %%
#Evaluating model

model.evaluate(test_data,test_labels)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9645
# [0.10506932437419891, 0.9645389914512634]

# %%
#Make predictions from test data

model.predict(train_data)
# Out:
# array([[9.88523960e-01],
#        [6.83954060e-02],
#        [9.93894100e-01],
#        [1.98906362e-02],
#        [9.95092690e-01],
#        [2.96095312e-02],
#        [9.96263683e-01],
#        [2.62922049e-03],
#        [9.87194955e-01],
#        [3.71867418e-03],
#        [9.93818045e-01],
#        [2.84773111e-03],
#        [9.90917325e-01],
#        [1.39254242e-01],
#        [9.98487353e-01],
#        [3.15049291e-03],
#        [9.97314513e-01],
#        [3.31073999e-04],
#        [8.95316362e-01],
#        [7.65383244e-04],
#        [9.86152530e-01],
#        [3.09014894e-08],
#        [9.81642783e-01],
#        [3.16604678e-06],
#        [9.90632534e-01],
#        [4.77211475e-02],
#        [9.91904080e-01],
#        [1.47819519e-04],
#        [9.97370183e-01],
#        [1.73950011e-05],
#        [9.85559106e-01],
#        [3.01510096e-04],
#        [9.86351371e-01],
#        [9.78720188e-03],
#        [9.18113708e-01],
#        [7.98732042e-04],
#        [9.93632197e-01],
# ...
